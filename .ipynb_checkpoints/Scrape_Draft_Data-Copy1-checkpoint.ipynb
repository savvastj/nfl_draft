# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url_2015 = "http://www.pro-football-reference.com/years/2015/draft.htm"

html = urlopen(url_2015)

soup = BeautifulSoup(html)
# Out:
# /home/savvas-mint/miniconda3/envs/py35/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
column_headers = [th.getText() for th in 
                  soup.findAll('tr', limit=2)[1].findAll('th')]

# %%
column_headers
# Out:
# ['Rnd',
#  'Pick',
#  'Tm',
#  '',
#  'Pos',
#  'Age',
#  'To',
#  'AP1',
#  'PB',
#  'St',
#  'CarAV',
#  'DrAV',
#  'G',
#  'Cmp',
#  'Att',
#  'Yds',
#  'TD',
#  'Int',
#  'Att',
#  'Yds',
#  'TD',
#  'Rec',
#  'Yds',
#  'TD',
#  'Tkl',
#  'Int',
#  'Sk',
#  'College/Univ',
#  '']

# %%
data_rows = soup.findAll('tr')[2:]  # skip the first 2 header rows

# %%
player_data = [[td.getText() for td in data_rows[i].findAll('td')]
            for i in range(len(data_rows))]

# %%
player_data
# Out:
# [['1',
#   '1',
#   'TAM',
#   'Jameis Winston',
#   'QB',
#   '21',
#   '2015',
#   '0',
#   '1',
#   '1',
#   '13',
#   '13',
#   '16',
#   '312',
#   '535',
#   '4042',
#   '22',
#   '15',
#   '53',
#   '210',
#   '6',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Florida St.',
#   'College Stats'],
#  ['1',
#   '2',
#   'TEN',
#   'Marcus Mariota',
#   'QB',
#   '21',
#   '2015',
#   '0',
#   '0',
#   '1',
#   '9',
#   '9',
#   '12',
#   '230',
#   '370',
#   '2818',
#   '19',
#   '10',
#   '34',
#   '252',
#   '2',
#   '1',
#   '41',
#   '1',
#   '',
#   '',
#   '',
#   'Oregon',
#   'College Stats'],
#  ['1',
#   '3',
#   'JAX',
#   'Dante Fowler Jr.',
#   'OLB',
#   '21',
#   '',
#   '0',
#   '0',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Florida',
#   'College Stats'],
#  ['1',
#   '4',
#   'OAK',
#   'Amari Cooper',
#   'WR',
#   '21',
#   '2015',
#   '0',
# ...

# %%
df = pd.DataFrame(player_data, columns=column_headers)

# %%
df.head()
# Out:
#   Rnd Pick   Tm                    Pos Age    To AP1 PB St      ...        \
# 0   1    1  TAM    Jameis Winston   QB  21  2015   0  1  1      ...
# 1   1    2  TEN    Marcus Mariota   QB  21  2015   0  0  1      ...
# 2   1    3  JAX  Dante Fowler Jr.  OLB  21         0  0  0      ...
# 3   1    4  OAK      Amari Cooper   WR  21  2015   0  1  1      ...
# 4   1    5  WAS   Brandon Scherff    T  23  2015   0  0  1      ...
#
#    Yds TD Rec   Yds TD Tkl Int Sk College/Univ
# 0  210  6                          Florida St.  College Stats
# 1  252  2   1    41  1                  Oregon  College Stats
# 2                                      Florida  College Stats
# 3   -3  0  72  1070  6                 Alabama  College Stats
# 4                                         Iowa  College Stats
#
# [5 rows x 29 columns]

# %%
df.tail()
# Out:
#       Rnd  Pick    Tm                     Pos   Age    To   AP1    PB    St  \
# 266     7   255   IND     Denzell Goode     T    24  2015     0     0     0
# 267     7   256   ARI  Gerald Christian    TE    24           0     0     0
# 268  None  None  None              None  None  None  None  None  None  None
# 269  None  None  None              None  None  None  None  None  None  None
# 270     5     1   STL     Isaiah Battle     T    22           0     0     0
#
#          ...         Yds    TD   Rec   Yds    TD   Tkl   Int    Sk  \
# 266      ...
# 267      ...
# 268      ...        None  None  None  None  None  None  None  None
# 269      ...        None  None  None  None  None  None  None  None
# 270      ...
#
#     College/Univ
# 266    Mars Hill
# 267   Louisville  College Stats
# 268         None           None
# 269         None           None
# 270      Clemson
#
# [5 rows x 29 columns]

# %%
tds = soup.select("#drafts td")

# %%
type(tds)
# Out:
# list

# %%
type(tds[0])
# Out:
# bs4.element.Tag

# %%
len(tds)
# Out:
# 7424

# %%
jameis = tds[3]

# %%
jameis
# Out:
# <td align="left" csk="Winston,Jameis"><strong><a href="/players/W/WinsJa00.htm">Jameis Winston</a></strong></td>

# %%
jameis.find("a")
# Out:
# bs4.element.Tag

# %%
len(jameis.contents)
# Out:
# 1

# %%
jameis
# Out:
# <td align="left" csk="Winston,Jameis"><strong><a href="/players/W/WinsJa00.htm">Jameis Winston</a></strong></td>

# %%
list(jameis.descendants)
# Out:
# [<strong><a href="/players/W/WinsJa00.htm">Jameis Winston</a></strong>,
#  <a href="/players/W/WinsJa00.htm">Jameis Winston</a>,
#  'Jameis Winston']

# %%
player_data2 = [[td.getText() for td in tds[i].findAll('td')]
                for i in range(len(tds))]

# %%
player_data2
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...

# %%
elements = scrape_css(css_selector, url_2015)

# %%
headers = [elem.text for elem in elements if elem.tag == "th"]

# %%
tds = [elem for elem in elements if elem.tag == "td"]

# %%
soup.select("//td[(((count(preceding-sibling::*) + 1) = 4) and parent::*)]//a")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-42-8dcd001adaea> in <module>()
# ----> 1 soup.select("//td[(((count(preceding-sibling::*) + 1) = 4) and parent::*)]//a")
#
# /home/savvas-mint/miniconda3/envs/py35/lib/python3.5/site-packages/bs4/element.py in select(self, selector, _candidate_generator, limit)
#    1398                 else:
#    1399                     raise NotImplementedError(
# -> 1400                         'Only the following pseudo-classes are implemented: nth-of-type.')
#    1401
#    1402             elif token == '*':
#
# NotImplementedError: Only the following pseudo-classes are implemented: nth-of-type.
